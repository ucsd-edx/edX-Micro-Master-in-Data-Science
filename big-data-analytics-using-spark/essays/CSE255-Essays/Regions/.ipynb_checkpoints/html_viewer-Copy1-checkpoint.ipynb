# %%
from IPython.display import display,HTML
display(HTML("SSSSBBBB.html"))
# Out:
# <h1>Region: SSSSBBBB</h1><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id_html</th>
#       <th>id_num</th>
#       <th>score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td><a href='https://github.com/ucsd-edx/CSE255-DSE230-Grading/tree/master/050'>A53227602</a></td>
#       <td>50</td>
#       <td>1.600000</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><a href='https://github.com/ucsd-edx/CSE255-DSE230-Grading/tree/master/043'>A53205530</a></td>
#       <td>43</td>
#       <td>0.250000</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><a href='https://github.com/ucsd-edx/CSE255-DSE230-Grading/tree/master/097'>A53214137</a></td>
#       <td>97</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><a href='https://github.com/ucsd-edx/CSE255-DSE230-Grading/tree/master/100'>A53206209</a></td>
#       <td>100</td>
# ...
