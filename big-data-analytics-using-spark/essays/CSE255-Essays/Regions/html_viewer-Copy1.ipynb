# %%
from IPython.display import display,HTML
display(HTML("BBBBSSBB.html"))
# Out:
# <h1>Region: BBBBSSBB</h1><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id_html</th>
#       <th>id_num</th>
#       <th>score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td><a href='https://github.com/ucsd-edx/CSE255-DSE230-Grading/tree/master/005'>A53201459</a></td>
#       <td>5</td>
#       <td>2.857143</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><a href='https://github.com/ucsd-edx/CSE255-DSE230-Grading/tree/master/134'>A53212517</a></td>
#       <td>134</td>
#       <td>1.875000</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><a href='https://github.com/ucsd-edx/CSE255-DSE230-Grading/tree/master/179'>A53218602</a></td>
#       <td>179</td>
#       <td>-0.333333</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><a href='https://github.com/ucsd-edx/CSE255-DSE230-Grading/tree/master/169'>A53090836</a></td>
#       <td>169</td>
# ...
