# %%
import ipyleaflet
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from ipyleaflet import (
    Map,
    Marker, basemap_to_tiles, basemaps,
    TileLayer, ImageOverlay,
    Polyline, Polygon, Rectangle, Circle, CircleMarker,
    GeoJSON,
    DrawControl,SplitMapControl
)

# %% [markdown]
# ## Visualizing the distribution coefficients on a map

# %% [markdown]
# ## Loading libraries and information

# %% [markdown]
# ### Load the required libraries

# %%
import pandas as pd
import numpy as np
import sklearn as sk
import urllib
import math

# %%
import findspark
findspark.init()

from pyspark import SparkContext
#sc.stop()
sc = SparkContext(master="local[3]",pyFiles=['lib/numpy_pack.py','lib/spark_PCA.py','lib/computeStatistics.py'])

from pyspark import SparkContext
from pyspark.sql import *
sqlContext = SQLContext(sc)

# %%
import numpy as np
from lib.numpy_pack import packArray,unpackArray
from lib.spark_PCA import computeCov
from lib.computeStatistics import *

# %% [markdown]
# ###  Load stations information

# %%
data_dir='../Data/Weather/'
# !du -sh $data_dir/*
# Out:
# 133M	../Data/Weather//CA.parquet
# 109M	../Data/Weather//CA.tgz
# 77M	../Data/Weather//NY.parquet
# 64M	../Data/Weather//NY.tgz
# 50M	../Data/Weather//STAT_CA.pickle
# 25M	../Data/Weather//STAT_NY.pickle
# 49M	../Data/Weather//STAT_WA.pickle
# 75M	../Data/Weather//WA.parquet
# 62M	../Data/Weather//WA.tgz
# 348K	../Data/Weather//Weather_Stations.tgz
# 7.6M	../Data/Weather//decon_WA_PRCP_s20.parquet
# 7.6M	../Data/Weather//recon_WA_PRCP_s20.parquet
# 420K	../Data/Weather//stations.parquet

# %%
stations_df=sqlContext.read.parquet(data_dir+'/stations.parquet')
stations_df.show(3)
# Out:
# +-----------+----------+--------+---------+---------+-----+----------------+
# |    Station|Dist_coast|Latitude|Longitude|Elevation|State|            Name|
# +-----------+----------+--------+---------+---------+-----+----------------+
# |USC00341900|   739.956|    36.3| -96.4667|    242.3|   OK|       CLEVELAND|
# |USC00428114|    908.22|    40.1|-111.6667|   1409.1|   UT|SPANISH FORK 1 S|
# |USC00165926|   23.8801| 29.7853| -90.1158|      0.9|   LA|   MARRERO 9 SSW|
# +-----------+----------+--------+---------+---------+-----+----------------+
# only showing top 3 rows

# %% [markdown]
# ### Load the reconstructions DataFrame
#
# For details about the columns in this DataFrame see the README notebook

# %%
### Read the data frame from a parquet file.

state='WA'
meas='PRCP_s20'

#read data
filename=data_dir+'/decon_%s_%s.parquet'%(state,meas)

df=sqlContext.read.parquet(filename)
print(df.count())
df.show(1)
# Out:
# 9581
# +-----------+-----------+--------------------+----+-----------------+------------------+-----------------+------------------+------------------+------------------+-----------------+------------------+-------------------+------------------+------------------+------------------+------------------+------------------+-------------------+-------------------+-----------------+
# |Measurement|    Station|              Values|Year|          coeff_1|           coeff_2|          coeff_3|           coeff_4|           coeff_5|        dist_coast|        elevation|          latitude|          longitude|              name|             res_1|             res_2|             res_3|             res_4|              res_5|           res_mean|        total_var|
# +-----------+-----------+--------------------+----+-----------------+------------------+-----------------+------------------+------------------+------------------+-----------------+------------------+-------------------+------------------+------------------+------------------+------------------+------------------+-------------------+-------------------+-----------------+
# |   PRCP_s20|USW00024281|[59 4E 96 4E D3 4...|1894|5.986781088327629|-10.97880195023953|53.29483824262072|-78.24795668262487|55.313624180511745|1.4553099870681763|5.800000190734863|47.650001525878906|-122.30000305175781|SEATTLE URBAN SITE|0.9976796519456039|0.9898763883132958|0.8059954653442658|0.4096148668001254|0.21153943679199733|0.04035152079373737|382801.5736999512|
# +-----------+-----------+--------------------+----+-----------------+------------------+-----------------+------------------+------------------+------------------+-----------------+------------------+-------------------+------------------+------------------+------------------+------------------+------------------+-------------------+-------------------+-----------------+
# only showing top 1 row

# %% [markdown]
# ## Compute the count and average of `coef_1` for each station.

# %%
#extract longitude and latitude for each station
feature='coeff_1'
sqlContext.registerDataFrameAsTable(df,'weather')
Query="SELECT station, latitude,longitude,elevation,Dist_coast,%s FROM weather"%feature
print(Query)
df1 = sqlContext.sql(Query)

df2=df1.groupby(['station','latitude','longitude','elevation','Dist_coast']).agg({"station": "count", feature: "mean"})
#df2=df1.groupby(['station']).agg({"station": "count", feature: "mean"})
pdf=df2.toPandas()
pdf.sort_values(by=['station'],inplace=True)
pdf.head(5)
# Out:
# SELECT station, latitude,longitude,elevation,Dist_coast,coeff_1 FROM weather
#          station   latitude   longitude   elevation  Dist_coast  \
# 57   USC00450008  46.965801 -123.829201    3.000000    1.311030
# 33   USC00450013  47.261398 -123.714699  132.600006   33.051102
# 218  USC00450094  46.799999 -122.316704  396.799988   42.074501
# 198  USC00450158  47.466702 -123.883301   64.000000   34.400002
# 17   USC00450176  48.511902 -122.613602    6.100000    0.681926
#
#      count(station)  avg(coeff_1)
# 57              123    693.976955
# 33               78   1412.601816
# 218              38     75.929413
# 198               7   1121.969447
# 17              107   -180.244466

# %%
# Find long/lat bounding box
max_long=pdf['longitude'].max()
min_long=pdf['longitude'].min()
max_lat=pdf['latitude'].max()
min_lat=pdf['latitude'].min()

# %%
#define a mapping from the range of the value to hex colors.
from matplotlib.colors import rgb2hex
_avg='avg(%s)'%feature
_min=pdf[_avg].min()
_max=pdf[_avg].max()
_min,_max

import pylab as plt
cmap=plt.get_cmap('gnuplot_r')
def get_color(val):
    x=(val-_min)/(_max-_min)
    return(rgb2hex(cmap(x)[:3]))

# %% [markdown]
# ## Map
# * Each circle is centered at a station.
# * The area of the circle corresponds to the number of years SNWD was recorded at the station.
# * The color fill of the circle corresponds to the value of `avg(coeff_1)` defined by color-bar.

# %%
#def color_bar(_min,_max)
import pylab as plt
from matplotlib.pyplot import xticks,yticks
figure(figsize=[10,1])
ax = plt.subplot(111)
vals=cmap(np.arange(0,1,0.005))[:,:3]
vals3=np.stack([vals]*10)
vals3.shape
ax.imshow(vals3);

midpoint=200.*-_min/(_max-_min)
xticks((0,midpoint,200),["%4.1f"%v for v in (_min,0.,_max)])
yticks(());

# %%
center = [(min_lat+max_lat)/2, (min_long+max_long)/2]
zoom = 6
#default_tiles=TileLayer(opacity=1.0),
m = Map( center=center, zoom=zoom)
left = TileLayer(url='https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png')
right = basemap_to_tiles(basemaps.Stamen.Terrain)
control = SplitMapControl(left_layer=left, right_layer=right)
m.add_control(control)
r = Rectangle(bounds=[[min_lat,min_long],[max_lat,max_long]], weight=5, fill_opacity=0.0)
m += r

lat_margin=(max_lat-min_lat)/4
long_margin=(max_long-min_long)/4
circles = []
for index,row in pdf.iterrows():
    _lat=row['latitude']
    _long=row['longitude']
    _count=row['count(station)']
    _coef=row[_avg]
    # taking sqrt of count so that the  area of the circle corresponds to the count
    c = Circle(location=(_lat,_long), radius=int(1200*np.sqrt(_count+0.0)), weight=1,
            color='#F00', opacity=0.8, fill_opacity=0.4,
            fill_color=get_color(_coef))
    circles.append(c)
    m.add_layer(c)
m
# Out:
# Map(basemap={'url': 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', 'max_zoom': 19, 'attribution': 'Map data (c) <a href="https://openstreetmap.org">OpenStreetMap</a> contributors'}, center=[47.29999923706055, -120.89039993286133], controls=(SplitMapControl(left_layer=TileLayer(options=['attribution', 'detect_retina', 'max_zoom', 'min_zoom', 'tile_size'], url='https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png'), right_layer=TileLayer(attribution='Map tiles by <a href="http://stamen.com/">Stamen Design</a>, under <a href="http://creativecommons.org/licenses/by/3.0">CC BY 3.0</a>. Data by <a href="http://openstreetmap.org/">OpenStreetMap</a>, under <a href="http://creativecommons.org/licenses/by-sa/3.0">CC BY SA</a>.', name='Stamen.Terrain', options=['attribution', 'detect_retina', 'max_zoom', 'min_zoom', 'tile_size'], url='http://stamen-tiles-a.a.ssl.fastly.net/terrain/{z}/{x}/{y}.png')),), layers=(TileLayer(base=True, max_zoom=19, min_zoom=1, options=['attribution', 'detect_retina', 'max_zoom', 'min_zoom', 'tile_size']), Rectangle(bounds=[[45.599998474121094, -124.7332992553711], [49.0, -117.04750061035156]], fill_opacity=0.0, options=['class_name', 'clickable', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'no_clip', 'opacity', 'pointer_events', 'smooth_factor', 'stroke', 'weight']), Circle(color='#F00', fill_color='#d14e00', fill_opacity=0.4, location=[46.96580123901367, -123.8292007446289], opacity=0.8, options=['class_name', 'clickable', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=13308, weight=1), Circle(color='#F00', fill_color='#aa1659', fill_opacity=0.4, location=[47.26139831542969, -123.7146987915039], opacity=0.8, options=['class_name', 'clickable', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=10598, weight=1), Circle(color='#F00', fill_color='#efad00', fill_opacity=0.4, location=[46.79999923706055, -122.31670379638672], opacity=0.8, options=['class_name', 'clickable', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=7397, weight=1), Circle(color='#F00', fill_color='#bb2800', fill_opacity=0.4, location=[47.46670150756836, -123.88330078125], opacity=0.8, options=['class_name', 'clickable', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=3174, weight=1), Circle(color='#F00', fill_color='#fae200', fill_opacity=0.4, location=[48.51190185546875, -122.61360168457031], opacity=0.8, options=['class_name', 'clickable', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=12412, weight=1), Circle(color='#F00', fill_color='#f9dd00', fill_opacity=0.4, location=[46.13330078125, -117.13330078125], opacity=0.8, options=['class_name', 'clickable', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=6572, weight=1), Circle(color='#F00', fill_color='#f5c800', fill_opacity=0.4, location=[45.809200286865234, -121.28109741210938], opacity=0.8, options=['class_name', 'clickable', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], radius=8400, weight=1), Circle(color='#F00', fill_color='#f0af00', fill_opacity=0.4, location=[48.200599670410156, -122.12809753417969], opacity=0.8, options=['class_name', 'clickable', 'color', 'dash_array', 'fill', 'fill_color', 'fill_opacity', 'line_cap', 'line_join', 'opacity', 'pointer_events', 'radius', 'stroke', 'weight'], rad ...

# %% [markdown]
# ### Something to try
# * Leaflet supports a variety of maps. See if you can get a topographical map as the background.

# %% [markdown]
# ### Is coef_1 related to elevation ?

# %%
pdf.plot.scatter(x='Dist_coast',y='avg(coeff_1)',figsize=(8,6));
grid()
xlim([-100,1000])
# Out:
# (-100, 1000)

# %% [markdown]
# ## Summary
# * We saw how to use `ipyLeaflet` to present data on top of maps.
# * We saw that in NY state, most of the snow accumulation is in the Adirondacks.
# * Snow accumulation increases with elevation, but the relationship is weak: locations with elevation 400-600 meters have widely varying accumulations of snow.

# %% [markdown]
# ## See you next time
