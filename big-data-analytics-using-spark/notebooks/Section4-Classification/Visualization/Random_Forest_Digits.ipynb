# %% [markdown]
# ## Random Forests

# %%
import sklearn.datasets as datasets
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
from IPython.core.display import display, HTML

from lib import RandomForestHelper as RFH
from lib import RFGraph

# %% [markdown]
# ## Example

# %%
Image(filename="Random-Forest-Introduction.jpg")

# %%
# %config IPCompleter.greedy=True

# %% [markdown]
# Refer: http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html

# %% [markdown]
# Parameters for a Random Forest:
#
# <ul>
# 	<li>n_estimators</li>
# 	<li>criterion</li>
# 	<li>max_features</li>
# 	<li>max_depth</li>
# 	<li>min_samples_split</li>
# 	<li>min_samples_leaf</li>
# 	<li>min_weight_fraction_leaf</li>
# 	<li>max_leaf_nodes</li>
# 	<li>min_impurity_split</li>
# 	<li>min_impurity_decrease</li>
# 	<li>bootstrap</li>
# 	<li>oob_score</li>
# 	<li>n_jobs</li>
# 	<li>random_state</li>
# 	<li>verbose</li>
# 	<li>warm_start</li>
# 	<li>class_weight</li>
# </ul>

# %%
D=datasets.load_digits()
D.keys()

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(D.data, D.target, test_size=0.3)
# Out:
# dict_keys(['data', 'target', 'target_names', 'images', 'DESCR'])

# %% [markdown]
# # The random forest classifier

# %% [markdown]
# Parameters being changed:
# 1. **Max_depth**: The deepest level to which a decision tree can go to
# 2. **n_estimators**: The number of decision trees that are generated and eventually used for majority voting

# %%
rf = RandomForestClassifier(max_depth=10, n_estimators=111)
rf = rf.fit(X_train, y_train)

# %% [markdown]
# ## Predicting Category
#
# 1. Different decision trees are generated from the input data.
# 2. For each sample, the category is decided based on the decision tree.
# 3. The final prediction is done by some form of ensemble learning on the outputs of the different trees. In this scenario, we use majority voting (Category that gets the most votes is predicted).

# %%
HTML(html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>DTree 0</th>
#       <th>DTree 1</th>
#       <th>DTree 2</th>
#       <th>DTree 3</th>
#       <th>DTree 4</th>
#       <th>DTree 5</th>
#       <th>DTree 6</th>
#       <th>DTree 7</th>
#       <th>DTree 8</th>
#       <th>DTree 9</th>
#       <th>DTree 10</th>
#       <th>DTree 11</th>
#       <th>DTree 12</th>
#       <th>DTree 13</th>
#       <th>DTree 14</th>
#       <th>DTree 15</th>
#       <th>DTree 16</th>
#       <th>DTree 17</th>
#       <th>DTree 18</th>
#       <th>DTree 19</th>
#       <th>DTree 20</th>
#       <th>DTree 21</th>
#       <th>DTree 22</th>
#       <th>DTree 23</th>
#       <th>DTree 24</th>
#       <th>DTree 25</th>
#       <th>DTree 26</th>
#       <th>DTree 27</th>
#       <th>DTree 28</th>
#       <th>DTree 29</th>
#       <th>DTree 30</th>
#       <th>DTree 31</th>
#       <th>DTree 32</th>
#       <th>DTree 33</th>
#       <th>DTree 34</th>
#       <th>DTree 35</th>
#       <th>DTree 36</th>
#       <th>DTree 37</th>
#       <th>DTree 38</th>
#       <th>DTree 39</th>
#       <th>DTree 40</th>
#       <th>DTree 41</th>
#       <th>DTree 42</th>
#       <th>DTree 43</th>
#       <th>DTree 44</th>
#       <th>DTree 45</th>
#       <th>DTree 46</th>
#       <th>DTree 47</th>
#       <th>DTree 48</th>
#       <th>DTree 49</th>
#       <th>DTree 50</th>
#       <th>DTree 51</th>
#       <th>DTree 52</th>
#       <th>DTree 53</th>
#       <th>DTree 54</th>
#       <th>DTree 55</th>
#       <th>DTree 56</th>
#       <th>DTree 57</th>
#       <th>DTree 58</th>
#       <th>DTree 59</th>
#       <th>DTree 60</th>
#       <th>DTree 61</th>
#       <th>DTree 62</th>
#       <th>DTree 63</th>
#       <th>DTree 64</th>
#       <th>DTree 65</th>
#       <th>DTree 66</th>
#       <th>DTree 67</th>
#       <th>DTree 68</th>
#       <th>DTree 69</th>
#       <th>DTree 70</th>
#       <th>DTree 71</th>
#       <th>DTree 72</th>
#       <th>DTree 73</th>
#       <th>DTree 74</th>
#       <th>DTree 75</th>
#       <th>DTree 76</th>
#       <th>DTree 77</th>
#       <th>DTree 78</th>
#       <th>DTree 79</th>
#       <th>DTree 80</th>
#       <th>DTree 81</th>
#       <th>DTree 82</th>
#       <th>DTree 83</th>
#       <th>DTree 84</th>
#       <th>DTree 85</th>
#       <th>DTree 86</th>
#       <th>DTree 87</th>
#       <th>DTree 88</th>
#       <th>DTree 89</th>
#       <th>DTree 90</th>
#       <th>DTree 91</th>
#       <th>DTree 92</th>
#       <th>DTree 93</th>
#       <th>DTree 94</th>
#       <th>DTree 95</th>
#       <th>DTree 96</th>
#       <th>DTree 97</th>
#       <th>DTree 98</th>
#       <th>DTree 99</th>
#       <th>DTree 100</th>
#       <th>DTree 101</th>
#       <th>DTree 102</th>
#       <th>DTree 103</th>
#       <th>DTree 104</th>
#       <th>DTree 105</th>
#       <th>DTree 106</th>
#       <th>DTree 107</th>
#       <th>DTree 108</th>
#       <th>DTree 109</th>
#       <th>DTree 110</th>
#       <th>Prediction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>21</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>126</th>
#       <td>2</td>
#       <td>1</td>
#       <td>2</td>
#       <td>2</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2</td>
#       <td>2</td>
#       <td>2</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2</td>
#       <td>2</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2</td>
#       <td>2</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>2</td>
#       <td>2</td>
#       <td>2</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>2</td>
#       <td>2</td>
#       <td>2</td>
#       <td>2</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2</td>
#       <td>2</td>
#       <td>1</td>
#       <td>1</td>
#       <td>2</td>
#       <td>1</td>
#       <td>2</td>
#       <td>2

# %% [markdown]
# ## Visualizing a specific Decision Tree from a Random Forest

# %% [markdown]
# legend = """Attributes:
#     <ul>
#         <li><b>X0, X1, X2, X3</b>: sepal length, sepal width, petal length, petal width</li>
#         <li><b>Samples</b>: Number of samples considered for building this decision tree</li>
#         <li><b>Value</b>: Number of samples in each of the three categories of flowers in order</li>
#     </ul>
#     """

# %%
RFGraph.generate_tree(rf, 0, height=500, width=400) #ith Decision Tree: Where i is the Decision Tree number according to the above table)
HTML(legend)
# Out:
# Decision Tree 0 :
# Attributes:
#     <ul>
#         <li><b>X0, X1, X2, X3</b>: sepal length, sepal width, petal length, petal width</li>
#         <li><b>Samples</b>: Number of samples considered for building this decision tree</li>
#         <li><b>Value</b>: Number of samples in each of the three categories of flowers in order</li>
#     </ul>

# %%
#To get information on ith value in the pandas dataframe
df.iloc[77]
# Out:
# sepal length (cm)    6.7
# sepal width (cm)     3.0
# petal length (cm)    5.0
# petal width (cm)     1.7
# Name: 77, dtype: float64

# %% [markdown]
# # Confidence Margin

# %%
p1 = []
p2 = []
p3 = []
for i in range(len(pred)):
    p1.append(1.0 * list(pred[i]).count(0)/len(pred[i]))       #List of Category 1 probabilities for all samples
    p2.append(1.0 * list(pred[i]).count(1)/len(pred[i]))       #List of Category 2 probabilities for all samples
    p3.append(1.0 * list(pred[i]).count(2)/len(pred[i]))       #List of Category 3 probabilities for all samples
    
RFGraph.generate_simplex(p1, p2, p3, y_test, legend=['Boundary', '0: Iris setosa', '1: Iris virginica', '2: Iris versicolor'])

# %% [markdown]
# **You are encouraged to explore the RandomForestCalssifier by altering parameters passed to it.**
