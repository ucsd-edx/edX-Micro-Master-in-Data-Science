# %%
Practice="""
PracticeFinal1": "TestPreparation/Combinatorics/sw10_1_7.imd",
	"PracticeFinal2": "TestPreparation/Poker/q1.imd",
	"PracticeFinal3": "TestPreparation/StarsAndBars/balls_bins_1_rs.imd",
	"PracticeFinal4": "TestPreparation/CumulativeDistributionFunctions/cdf_exp_uni.imd",
	"PracticeFinal5": "TestPreparation/ConditionalProbability/ConditionalProbability.imd",
	"PracticeFinal6": "TestPreparation/PokerConditional/poker_cond2_2.imd",
	"PracticeFinal7": "TestPreparation/BayesConditional/Bayes2.imd",
	"PracticeFinal8": "TestPreparation/ExpectationVariance/cov_dep_uncor2.imd",
        "PracticeFinal9": "TestPreparation/ExpectationVariance/cov_dep_asym.imd",  #### File needs to be created.
        "PracticeFinal10": "TestPreparation/ExpectationVariance/probs70.imd",
        "PracticeFinal11": "TestPreparation/MarkovChebyshev/MarkovChebyshev2.imd",
        "PracticeFinal12": "TestPreparation/Covariance/2.imd",
        "PracticeFinal13": "TestPreparation/ExponentialPoisson/ur_pb_9_1.imd",
	"PracticeFinal14": "TestPreparation/HeavyLightTails/HeavyLightTails1.imd",
	"PracticeFinal15": "TestPreparation/HypothesisTesting/drug.imd",
"""
import re
pattern=re.compile(r'.*TestPreparation/([^"]+)"')
Practice_names=[]
for line in Practice.splitlines():
    M=pattern.match(line)
    if M:
        Practice_names.append(M.group(1))
all_names=!ls */*.imd
for name in all_names:
    if name in Practice_names:
        #print 'Practice:',name
        continue
    else:
        print '%load ',name
# Out:
# %load  BayesConditional/probs_43_w_randomization.imd
# %load  Combinatorics/sw10_1_33.imd
# %load  ConditionalProbability/Independence.imd
# %load  Covariance/1.imd
# %load  ExpectationVariance/cov_dep_anitcorr.imd
# %load  ExpectationVariance/cov_dep_uncor1.imd
# %load  ExpectationVariance/covariance.imd
# %load  ExponentialPoisson/ur_pb_9_2.imd
# %load  HeavyLightTails/HeavyLightTails2.imd
# %load  HypothesisTesting/gust63.imd
# %load  MarkovChebyshev/MarkovChebyshev1.imd
# %load  Poker/q4_1.imd
# %load  Poker/q4_2.imd
# %load  PokerConditional/poker_cond4_2.imd
# %load  StarsAndBars/ShareCandy_ZZ.imd
# %load  final2016/1.imd
# %load  final2016/CDFProblem1.imd
# %load  final2016/CDFProblem2.imd
# %load  final2016/MarkovChebyshevA.imd
# %load  final2016/ShareCandy_ZZ.imd
# %load  final2016/cov_asym.imd
# %load  final2016/cov_dep_uncor1.imd
# %load  final2016/cov_dep_uncor2.imd
# %load  final2016/dep_uncor1.imd
# %load  final2016/gust63.imd
# ...

# %%
# !ls final2016/
# Out:
# 1.imd                        cov_dep_uncor2.imd
# CDFProblem1.imd              dep_uncor1.imd
# CDFProblem2.imd              gust63.imd
# MarkovChebyshevA.imd         probs_43_w_randomization.imd
# ShareCandy_ZZ.imd            q4_2.imd
# cov_asym.imd                 sw10_1_33.imd
# cov_dep_uncor1.imd           ur_pb_9_2.imd

# %%
# %%writefile final2016/probs_43_w_randomization.imd
# ```python
# # random variables (no need to import random library)
# p_men = random.randrange(6,8,1)
# p_women = random.randrange(3,5,1)
# p_male_given_colorblind = p_men/(p_men+p_women)
#
# # Solutions with variables converted to string
# # Make sure you name the solution with part id at the end. e.g. 'solution1' will be solution for part 1.
# solution1 = "{0}/({0}+{1})".format(p_men, p_women)
#
#
# # Group all solutions into a list
# solutions = [solution1]
# ```
#
# ## Bayes: Gender and color-blindness
# (5 points)
#
# Suppose that there are equal numbers of men and women in the world, and that \$p_men% of men are colorblind \$p_women% of women are colorblind. A person is chosen at random and found to be colorblind. What is the probability that the person is male? In other words, what is
# $P(\text{male}|\text{colorblind})$?
#
# [_]
#
# ### Hints
#
# * Use the following equation derived from Bayes Rule:
#
# $$P(\text{male}|\text{colorblind}) = \frac{P(\text{male}, \text{colorblind)}}{P(\text{colorblind)}}
# =\frac{P(\text{colorblind}|\text{male})P(\text{male})}{P(\text{colorblind})}$$
#
# * The denominator of the above equation can be calulated using the Law of total probability as follows:
#
# $$P(\text{colorblind}) = P(\text{male}, \text{colorblind}) + P(\text{female}, \text{colorblind}) \\
# = P(\text{colorblind}|\text{male})P(\text{male}) + P(\text{colorblind}|\text{female})P(\text{female})$$
# Out:
# Overwriting final2016/probs_43_w_randomization.imd

# %%
# %%writefile final2016/CDFProblem1.imd
# ### CDF problem (version 1)
# (15 points)
#
# #### Figure
# Sequence of $(x,cdf(x))$ pairs is:
#
# (-4,0),(-3,0),(-1,0.3),(1,0.5),(1.999,0.6),(2,0.8),(3,1),(4,1)
#
# ---
# The figure above corresponds to the CDF of a
# mixture of two uniform distributions and a point mass.
#
# Fill in the quantities below.
#
# All quantities are multiples of 0.1
#
# * There is a uniform component from [  -3] to [  1 ] whose weight is [0.4]
# * There is a uniform component from [  -1] to [  3 ] whose we ight is [0.4]
# * There is a point mass distribution at [2] whose weight is [0.2]
# Out:
# Overwriting final2016/CDFProblem1.imd

# %%
# %%writefile final2016/CDFProblem2.imd
#
# ### CDF problem (version 2)
# (15 points)
#
# #### Figure
# Sequence of $(x,cdf(x))$ pairs is:
#
# (-2,0),(-1,0),(0,0.2),(1,0.5),(1.999,0.6),(2,0.9),(3,1),(4,1)
#
# ---
# The figure above corresponds to the CDF of a
# mixture of two uniform distributions and a point mass.
#
# Fill in the quantities below.
#
# All quantities are multiples of 0.1
#
# * There is a uniform component from [  -1] to [  1 ] whose weight is [0.4]
# * There is a uniform component from [  0] to [  3 ] whose weight is [0.3]
# * There is a point mass distribution at [2] whose weight is [0.3]
# Out:
# Overwriting final2016/CDFProblem2.imd

# %%
# %%writefile final2016/sw10_1_33.imd
# ```python
# # Solutions with variables converted to string
# # Make sure you name the solution with part id at the end. e.g. 'solution1' will be solution for part
# #import random
# a=random.randrange(3,5,1)
#
# solution1 = '7**{}'.format(a)
# solution2 = 'P({0},{1})'.format(7,a)
# solution3 = '7**({}-1)'.format(a)
# solution4 = solution3
# solution5 = '2*'+solution3
#
# solutions=[solution1, solution2, solution3, solution4, solution5]
# solutions
# ```
#
# ## Combinatorics: letter combinations
# (9 points)
#
# If \$a-letter words are formed from the letters A, B, C, D, E, F, G, how many such words are possible for each of the following conditions:
#
# a. No condition is imposed.
#
# Your answer is :
#
# [_]
#
# b. No letter can be repeated in a word.
#
# Your answer is :
#
# [_]
#
# c. Each word must begin with the letter A and letters can be repeated.
#
# Your answer is :
#
# [_]
#
# d. The letter C must be at the end and letters can be repeated.
#
# Your answer is :
#
# [_]
#
# e. The second letter must be a vowel and letters can be repeated.
#
# Your answer is :
#
# [_]
# Out:
# Overwriting final2016/sw10_1_33.imd

# %%
#%%writefile  final2016/1.imd
```python
# Solutions with variables converted to string
# Make sure you name the solution with part id at the end. e.g. 'solution1' will be solution for part 1. 
option1 = ('T', 'F')
solution1 = "F"
option2 = ('T', 'F')
solution2 = "F"
option3 = ('T', 'F')
solution3 = "F"
option4 = ('T', 'F')
solution4 = "F"
solutions=[solution1, solution2, solution3, solution4]

```
## Covariance and Dependence
(10 points)

\{ image(src="/static/tilt_ellipse.png" style="width:200px;height:200px;") \}

Does a joint distribution whose shape is a tilted ellipse 
(not parallel to either axis, see figure) 
imply that X and Y are independent?

[_choice]

Does it imply that their covariance is zero?

[_choice]

Does it imply that their correlation coefficient is zero?

[_choice]

Is their correlation coefficient one?

[_choice]
# Out:
#   File "<ipython-input-57-a3cd2c94e8d9>", line 2
#     ```python
#              ^
# SyntaxError: invalid syntax

# %%
# %%writefile final2016/cov_dep_uncor1.imd
# ```python
# #### Written by Yoav Freund 11/3/2016
#
# # Solutions with variables converted to string
# # Make sure you name the solution with part id at the end. e.g. 'solution1' will be solution for part 1.
#
# import numpy as np
#
# X_vals=np.array([1,2,3])
# Y_vals=np.array([1,2,3])
#
# # this imd can generate a number of different problems, each for a different matrix
# # the matrices are specified here:
#
#
# matrices_str = {
# 'dep_corr1':np.array([["1./3","0","0"],["0","1./3","0"],["0","0","1./3"]]),
# 'indep_uncor': np.array([["0.1","0","0.4"],["0","0","0"],["0.1","0","0.4"]]),
# 'dep_uncor': np.array([["0.2","0","0.2"],["0","0.2","0"],["0.2","0","0.2"]]),
# 'dep_anticorr':np.array([["0","0","1./3"],["0","1./3","0"],["1./3","0","0"]]),
# 'dep_uncor1': np.array([["0.2","0","0.2"],["0","0.2","0"],["0.2","0","0.2"]]),
# 'dep_uncor2': np.array([["0.25","0","0"],["0","0","0.5"],["0.25","0","0"]]),
# 'asym': np.array([["0.2","0","0"],["0","0","0.5"],["0.3","0","0"]])
#         }
#
# matrices={}
# for key in matrices_str.keys():
#     M=matrices_str[key]
#     N=np.zeros(M.shape)
#     for i in range(M.shape[0]):
#         for j in range(M.shape[1]):
#             N[i,j]=eval(M[i,j])
#     matrices[key]=N
#
# problem='dep_uncor1'
#
# joint=matrices[problem]
# joint_str = matrices_str[problem]
#
# joint00 = joint_str[0,0]
# joint01 = joint_str[0,1]
# joint02 = joint_str[0,2]
# joint10 = joint_str[1,0]
# joint11 = joint_str[1,1]
# joint12 = joint_str[1,2]
# joint20 = joint_str[2,0]
# joint21 = joint_str[2,1]
# joint22 = joint_str[2,2]
#
#
# marginal_X = np.sum(joint,axis=0)
# marginal_Y = np.sum(joint,axis=1)
#
# mean_X=np.dot(marginal_X,X_vals)
# mean_Y=np.dot(marginal_Y,Y_vals)
#
# X_Nvals=X_vals-mean_X
# Y_Nvals=Y_vals-mean_Y
#
# var_X=np.dot(marginal_X,X_Nvals**2)
# var_Y=np.dot(marginal_Y,Y_Nvals**2)
#
# xy=np.outer(Y_vals,X_vals)
# Nxy=np.outer(Y_Nvals,X_Nvals)
#
# Cov = np.sum(np.multiply(Nxy,joint))
# Exy = np.sum(np.multiply(xy,joint))
#
# #print Exy, Cov, Cov/np.sqrt(var_X*var_Y)
# independent = 0.01 > np.sum((np.outer(marginal_Y,marginal_X)-joint)**2)
#
# # Dist of X
# solution1="+".join(joint_str[:,0])
# solution2="+".join(joint_str[:,1])
# solution3="+".join(joint_str[:,2])
# marginal_X_str = [solution1, solution2, solution3]
# solution4="+".join(["((%s) * (%.2f))"%(marginal_X_str[i],X_vals[i]) for i in range(len(X_vals))])
# solution5="+".join(["((%s) * ((%.2f)^2))"%(marginal_X_str[i],X_Nvals[i]) for i in range(len(X_vals))])
#
# # Dist of Y
# solution6="+".join(joint_str[0,:])
# solution7="+".join(joint_str[1,:])
# solution8="+".join(joint_str[2,:])
# marginal_Y_str = [solution6, solution7, solution8]
# solution9="+".join(["((%s) * (%.2f))"%(marginal_Y_str[i],Y_vals[i]) for i in range(len(Y_vals))])
# solution10="+".join(["((%s) * ((%.2f)^2))"%(marginal_Y_str[i],Y_Nvals[i]) for i in range(len(Y_vals))])
#
# #Interactions between X and Y
# flat_xy=xy.flatten()
# flat_joint=joint_str.flatten()
# solution11="+".join(["((%s) * (%.2f))"%(flat_joint[i],flat_xy[i]) for i in range(len(flat_xy))])
# solution12="{0}-({1}*{2})".format(Exy,mean_X,mean_Y)
# solution13="{0}/sqrt({1}*{2})".format(Cov,var_X,var_Y)
# solution14=str(1*independent)
# solutions=[solution1,solution2,solution3,solution4,solution5,solution6,solution7,solution8,
#            solution9,solution10,solution11,solution12,solution13,solution14]
# print 'joint=\n',joint
# print 'np.outer(marginal_Y,marginal_X)=\n',np.outer(marginal_Y,marginal_X)
# print 'mean_X,Mean_Y = ',mean_X,mean_Y
# print 'X_Nvals=',X_Nvals
# print 'Y_Nvals=',Y_Nvals
# print 'Nxy=\n',Nxy
# print 'Cov=',Cov
# print '\n'.join(solutions)
# ```
#
# ### Covariance Calculations (Version 1)
# (10 points)
#
# Suppose X,Y are discrete random variables whose joint distribution is
#
# <table align="center" border="1" cellpadding="1" cellspacing="1" style="width:500px">
# 	<caption>Joint probabilities</caption>
# 	<thead>
# 		<tr>
# 			<th scope="row"></th>
# 			<th scope="col" style="text-align: center; vertical-align: bottom;">x=1</th>
# 			<th scope="col" style="text-align: center; vertical-align: bottom;">x=2</th>
# 			<th scope="col" style="text-align: center; vertical-align: bottom;">x=3</th>
# 		</tr>
# 	</thead>
# 	<tbody>
# 		<tr>
# 			<th scope="row" style="text-align:center; vertical-align:bottom">y=1</th>
# 			<td style="text-align:center; vertical-align:bottom">\$joint00</td>
# 			<td style="text-align:center; vertical-align:bottom">\$joint01</td>
# 			<td style="text-align:center; vertical-align:bottom">\$joint02</td>
# 		</tr>
# 		<tr>
# 			<th scope="row" style="text-align:center; vertical-align:bottom">y=2</th>
# 			<td style="text-align:center; vertical-align:bottom">\$joint10</td>
# 			<td style="text-align:center; vertical-align:bottom">\$joint11</td>
# 			<td style="text-align:center; vertical-align:bottom">\$joint12</td>
# 		</tr>
# 		<tr>
# 			<th scope="row" style="text-align:center; vertical-align:bottom">y=3</th>
# 			<td style="text-align:center; vertical-align:bottom">\$joint20</td>
# 			<td style="text-align:center; vertical-align:bottom">\$joint21</td>
# 			<td style="text-align:center; vertical-align:bottom">\$joint22</td>
# 		</tr>
# 	</tbody>
# </table>
#
# ###(1) What is the distribution over $X$?
#
# $P(X=1)=$
#
# [_]
#
# $P(X=2)=$
#
# [_]
#
# $P(X=3)=$
#
# [_]
#
#
# What is $E(X)$ ?
#
# [_]
#
# What is $Var(X)$ ?
#
# [_]
#
#
# ###(2) What is the distribution over $Y$?
#
# $P(Y=1)=$
#
# [_]
#
# $P(Y=2)=$
#
# [_]
#
# $P(Y=3)=$
#
# [_]
#
# What is $E(Y)$ ?
#
# [_]
#
# What is $Var(Y)$ ?
#
# [_]
#
# ###(3) What is the relationship between $X$ and $Y$ ?
#
# What is $E(XY)$ ?
#
# [_]
#
# What is $Cov(X,Y)$ ?
#
# [_]
#
# What is $Corr(X,Y)$ ?
#
# [_]
#
# Are $X$ and $Y$ independent (1=independent, 0=dependent)?
#
# [_]
# Out:
# Overwriting final2016/cov_dep_uncor1.imd

# %%
# %%writefile final2016/cov_dep_uncor2.imd
# #```python
# #### Written by Yoav Freund 11/3/2016
#
# # Solutions with variables converted to string
# # Make sure you name the solution with part id at the end. e.g. 'solution1' will be solution for part 1.
#
# import numpy as np
#
# X_vals=np.array([1,2,3])
# Y_vals=np.array([1,2,3])
#
# # this imd can generate a number of different problems, each for a different matrix
# # the matrices are specified here:
#
#
# matrices_str = {
# 'dep_corr1':np.array([["1./3","0","0"],["0","1./3","0"],["0","0","1./3"]]),
# 'indep_uncor': np.array([["0.1","0","0.4"],["0","0","0"],["0.1","0","0.4"]]),
# 'dep_uncor': np.array([["0.2","0","0.2"],["0","0.2","0"],["0.2","0","0.2"]]),
# 'dep_anticorr':np.array([["0","0","1./3"],["0","1./3","0"],["1./3","0","0"]]),
# 'dep_uncor1': np.array([["0.2","0","0.2"],["0","0.2","0"],["0.2","0","0.2"]]),
# 'dep_uncor2': np.array([["0.25","0","0"],["0","0","0.5"],["0.25","0","0"]]),
# 'asym': np.array([["0.2","0","0"],["0","0","0.5"],["0.3","0","0"]])
#         }
#
# matrices={}
# for key in matrices_str.keys():
#     M=matrices_str[key]
#     N=np.zeros(M.shape)
#     for i in range(M.shape[0]):
#         for j in range(M.shape[1]):
#             N[i,j]=eval(M[i,j])
#     matrices[key]=N
#
# problem='dep_uncor2'
#
# joint=matrices[problem]
# joint_str = matrices_str[problem]
#
# joint00 = joint_str[0,0]
# joint01 = joint_str[0,1]
# joint02 = joint_str[0,2]
# joint10 = joint_str[1,0]
# joint11 = joint_str[1,1]
# joint12 = joint_str[1,2]
# joint20 = joint_str[2,0]
# joint21 = joint_str[2,1]
# joint22 = joint_str[2,2]
#
#
# marginal_X = np.sum(joint,axis=0)
# marginal_Y = np.sum(joint,axis=1)
#
# mean_X=np.dot(marginal_X,X_vals)
# mean_Y=np.dot(marginal_Y,Y_vals)
#
# X_Nvals=X_vals-mean_X
# Y_Nvals=Y_vals-mean_Y
#
# var_X=np.dot(marginal_X,X_Nvals**2)
# var_Y=np.dot(marginal_Y,Y_Nvals**2)
#
# xy=np.outer(Y_vals,X_vals)
# Nxy=np.outer(Y_Nvals,X_Nvals)
#
# Cov = np.sum(np.multiply(Nxy,joint))
# Exy = np.sum(np.multiply(xy,joint))
#
# #print Exy, Cov, Cov/np.sqrt(var_X*var_Y)
# independent = 0.01 > np.sum((np.outer(marginal_Y,marginal_X)-joint)**2)
#
# # Dist of X
# solution1="+".join(joint_str[:,0])
# solution2="+".join(joint_str[:,1])
# solution3="+".join(joint_str[:,2])
# marginal_X_str = [solution1, solution2, solution3]
# solution4="+".join(["((%s) * (%.2f))"%(marginal_X_str[i],X_vals[i]) for i in range(len(X_vals))])
# solution5="+".join(["((%s) * ((%.2f)^2))"%(marginal_X_str[i],X_Nvals[i]) for i in range(len(X_vals))])
#
# # Dist of Y
# solution6="+".join(joint_str[0,:])
# solution7="+".join(joint_str[1,:])
# solution8="+".join(joint_str[2,:])
# marginal_Y_str = [solution6, solution7, solution8]
# solution9="+".join(["((%s) * (%.2f))"%(marginal_Y_str[i],Y_vals[i]) for i in range(len(Y_vals))])
# solution10="+".join(["((%s) * ((%.2f)^2))"%(marginal_Y_str[i],Y_Nvals[i]) for i in range(len(Y_vals))])
#
# #Interactions between X and Y
# flat_xy=xy.flatten()
# flat_joint=joint_str.flatten()
# solution11="+".join(["((%s) * (%.2f))"%(flat_joint[i],flat_xy[i]) for i in range(len(flat_xy))])
# solution12="{0}-({1}*{2})".format(Exy,mean_X,mean_Y)
# solution13="{0}/sqrt({1}*{2})".format(Cov,var_X,var_Y)
# solution14=str(1*independent)
# solutions=[solution1,solution2,solution3,solution4,solution5,solution6,solution7,solution8,
#            solution9,solution10,solution11,solution12,solution13,solution14]
# #print k, dic_key
# #print 'joint=\n',joint
# #print 'np.outer(marginal_Y,marginal_X)=\n',np.outer(marginal_Y,marginal_X)
# #print 'mean_X,Mean_Y = ',mean_X,mean_Y
# #print 'X_Nvals=',X_Nvals
# #print 'Y_Nvals=',Y_Nvals
# #print 'Nxy=\n',Nxy
# #print 'Cov=',Cov
# #print '\n'.join(solutions)
# ```
#
# ### Covariance Calculations (Version 2)
# (10 points)
#
#
# Suppose X,Y are discrete random variables whose joint distribution is
#
# <table align="center" border="1" cellpadding="1" cellspacing="1" style="width:500px">
# 	<caption>Joint probabilities</caption>
# 	<thead>
# 		<tr>
# 			<th scope="row"></th>
# 			<th scope="col" style="text-align: center; vertical-align: bottom;">x=1</th>
# 			<th scope="col" style="text-align: center; vertical-align: bottom;">x=2</th>
# 			<th scope="col" style="text-align: center; vertical-align: bottom;">x=3</th>
# 		</tr>
# 	</thead>
# 	<tbody>
# 		<tr>
# 			<th scope="row" style="text-align:center; vertical-align:bottom">y=1</th>
# 			<td style="text-align:center; vertical-align:bottom">\$joint00</td>
# 			<td style="text-align:center; vertical-align:bottom">\$joint01</td>
# 			<td style="text-align:center; vertical-align:bottom">\$joint02</td>
# 		</tr>
# 		<tr>
# 			<th scope="row" style="text-align:center; vertical-align:bottom">y=2</th>
# 			<td style="text-align:center; vertical-align:bottom">\$joint10</td>
# 			<td style="text-align:center; vertical-align:bottom">\$joint11</td>
# 			<td style="text-align:center; vertical-align:bottom">\$joint12</td>
# 		</tr>
# 		<tr>
# 			<th scope="row" style="text-align:center; vertical-align:bottom">y=3</th>
# 			<td style="text-align:center; vertical-align:bottom">\$joint20</td>
# 			<td style="text-align:center; vertical-align:bottom">\$joint21</td>
# 			<td style="text-align:center; vertical-align:bottom">\$joint22</td>
# 		</tr>
# 	</tbody>
# </table>
#
# ### What is the distribution over $X$?
#
# $P(X=1)=$
#
# [_]
#
# $P(X=2)=$
#
# [_]
#
# $P(X=3)=$
#
# [_]
#
#
# What is $E(X)$ ?
#
# [_]
#
# What is $Var(X)$ ?
#
# [_]
#
#
# ###(2) What is the distribution over $Y$?
#
# $P(Y=1)=$
#
# [_]
#
# $P(Y=2)=$
#
# [_]
#
# $P(Y=3)=$
#
# [_]
#
# What is $E(Y)$ ?
#
# [_]
#
# What is $Var(Y)$ ?
#
# [_]
#
# ###(3) What is the relationship between $X$ and $Y$ ?
#
# What is $E(XY)$ ?
#
# [_]
#
# What is $Cov(X,Y)$ ?
#
# [_]
#
# What is $Corr(X,Y)$ ?
#
# [_]
#
# Are $X$ and $Y$ independent (1=independent, 0=dependent)?
#
# [_]
# Out:
# Overwriting final2016/cov_dep_uncor2.imd

# %%
# %%writefile final2016/ur_pb_9_2.imd
# ```python
# #import random
# m = random.randrange(11,40,1)/10.0
# a = random.randrange(1,7,1)
#
# t1 = random.randrange(10,20,1)
# t2 = random.randrange(t1+1,30,1)
# print t1,t2
#
# exp_cdf="1-exp(-{0}*{1})"
#
# solution1 = "{0}^{{{1}}}/{1}!/e^{{{0}}}".format(m,a)
# solution2 = "0"
# solution3 = exp_cdf.format(m,t2)+"-"+exp_cdf.format(m,t1)
# solutions = [solution1,solution2,solution3]
# solutions
# ```
#
# ### Poisson process
# (10 points)
#
# A professor schedules office hours for his students. He finds that the arrivals of the
# students follow a poisson process with an average rate of $\gamma =$ \$m
#
# What is the probability that the number of students that arrive during a particular
# hour is \$a?
#
# [_]
#
# What is the probability that the time between consecutive arrivals is
# exactly \t1 minutes?
#
# [_]
#
# What is the probability that the time between consecutive student arrivals
# is between \t1 and \t2 ?
#
# [_]
# Out:
# Overwriting final2016/ur_pb_9_2.imd

# %%
# %%writefile final2016/HeavyLightTails2.imd
# ```python
# showPartialCorrectAnswers = 1
# n = random.randrange(50,100)
# k = random.randrange(20,30)
#
# option1 = ('-1','0','infinity')
# option2 = ('-1','0','infinity')
# option3 = ('-1','0','infinity')
# option4 = ('-1','0','infinity')
# option5 = ('-1','0','infinity')
# option6 = ('-1','0','infinity')
# option7 = ('-1','0','infinity')
#
# solution1 = "-1"
# solution2 = "infinity"
# solution3 = "infinity"
# solution4 = "0"
# solution5 = "infinity"
# solution6 = "infinity"
# solution7 = "0"
# solution8 = "1.645/1.082"
# solution9 = "sqrt(1.645/1.082)"
# #solution10 = "0"
# #solution11 = "{0}*1.645/1.082".format(n)
# #solution12 = "sqrt({0}*1.645/1.082)".format(n)
# #solution13 = "{0}*1.645/1.082/{1}^2".format(n,k)
#
# solutions = [solution1,solution2,solution3,solution4,solution5,solution6,solution7,solution8,solution9]
# ```
#
# ## Heavy and light tails
# (10 points)
#
# ### Some Useful Facts
#
# $$\sum_{i=1}^{\infty}{\frac{1}{i}} = \infty$$
#
# Use the following approximations:
#
# $$\sum_{i=1}^{\infty}{\frac{1}{i^2}} \approx 1.645$$
#
# $$\sum_{i=1}^{\infty}{\frac{1}{i^3}} \approx 1.202$$
#
# $$\sum_{i=1}^{\infty}{\frac{1}{i^4}} \approx 1.082$$
#
# Use **inf** in an answer box to denote infinity.
# And use **-1** to denote undefined.
#
#
# ### Properties of Random Variable X
#
# Let X be a random variable over the integers $\mathbb{Z} = \{...-2,-1,0,1,2,...\}$.
#
# Let $P(X=0)=0$ and for $i \neq 0$ let $P(X=i) = \frac{1}{Z_{\alpha}|i|^\alpha}$ where $Z_{\alpha}$ is the **normalizing factor** $Z_{\alpha} = \sum_{i=-\infty}^{\infty}{1/|i|^{\alpha}}$.  Note that $Z_{\alpha}$ needs to be finite for this distribution to be well defined.
#
# For $\alpha=2$:
#
# What is $E[X]$?
#
# [_choice]
#
# What is $var[X]$?
#
# [_choice]
#
# What is $std[X]$?
#
# [_choice]
#
# For $\alpha=3$:
#
# What is $E[X]$?
#
# [_choice]
#
# What is $var[X]$?
#
# [_choice]
#
# What is $std[X]$?
#
# [_choice]
#
# For $\alpha=4$:
#
# What is $E[X]$?
#
# [_choice]
#
# What is $var[X]$?
#
# [_]
#
# What is $std[X]$?
#
# [_]
#
# Hint: To compute both the expected value and variances above, split the infinite
# summation $\sum_{i=-\infty}^{\infty}(\cdot)$ into two parts:
# $\sum_{i=-\infty}^{-1}(\cdot)$ and $\sum_{i=1}^{\infty}(\cdot)$.
# Out:
# Overwriting final2016/HeavyLightTails2.imd

# %%
# Sums of iid samples from X

For this part, let $X$ be defined as above for $\alpha=4$.  

Define the random variable $Y_{\$n} = \sum_{i=1}^{\$n}{X_i}$, $X_i$ independent identically distributed according to $X$.

Using linearity of expectation, what is $E[Y_{\$n}]$?  

[_]

Using the fact that the $X_i$ random variables are independent and identically
distributed, what is $var[Y_{\$n}]$?  

[_]

What about the the standard deviation $std[Y_{\$n}]$?  

[_]

Using Chebyshev's inequality, what is a bound on the $P(|Y_{\$n}| > \$k)$?  

[_]

RECALL:

Chebyshev's inequality states:

Let X be a random variable with finite expected value $\mu$ and finite non-zero variance $\sigma^2$. Then for any real number $\$k > 0$, $\Pr(|X-\mu|\geq k\sigma) \leq \frac{1}{k^2}$, which is the same as $\mathbb{P}(|X-\mathbb{E}(X)| \geq a) \leq \frac{\textrm{Var}(X)}{a^2}$ for any a>0.
# Out:
#   File "<ipython-input-62-f8a777b5cc59>", line 3
#     For this part, let $X$ be defined as above for $\alpha=4$.
#            ^
# SyntaxError: invalid syntax

# %%
# %%writefile final2016/gust63.imd
# ```python
# option1 = ('yes', 'no', 'can\'t tell')
# solution1 = "no"
# option2 = ('yes', 'no', 'can\'t tell')
# solution2 = "yes"
# option3 = ('yes', 'no', 'can\'t tell')
# solution3 = "can't tell"
# solutions=[solution1, solution2, solution3]
#
# ```
# ### Hypothesis testing and confidence intervals
# (5 points)
#
# We are given a sample $D$ drawn from a normal distribution ${\cal N}(\mu,\sigma)$. We know that the distribution is normal, but we don't know what is the value of the standard deviation $\sigma$ or the mean $\mu$
#
# We consider the relationship between two statistical calculations:
# * **Statistical test:** The Null hypothesis is that the mean $\mu$ is zero. The alternative hypothesis is that it is that $\mu \neq 0$. The test takes $D$ and a significance level parameter $\alpha>0$ as input and output "reject" or "fail". The requirement is that if the null hypothesis is correct, the probability of rejection is at most $\alpha$.
#
# * **Estimation:** An estimator takes as input the sample $D$ and a confidence level $\beta$ outputs an interval $(a,b)$ (Note that $a$ and $b$ are random variables). The requirement is that the the the probability that $a < \mu < b$ is at least $\beta$. In other words, the probability of a sample $D$ such that $\mu \leq a$ or $b \leq \mu$ is at most $1-\beta$.
#
# Answer the following questions.
#
# (1)  Suppose that for a given data set of $D$, a 95% confidence interval is calculated to be (-3.45,1.78).  If you were to perform a hypothesis test at the 5% significance level to test the null hypothesis, would you reject it?  Answer "yes", "no", or "can't tell".
#
# [_choice]
#
# (2)  Suppose that for a given data set of $D$, a 99% confidence interval is calculated to be (-10.77,-2.35).  If you were to perform a hypothesis test at the 3% significance level to test the null hypothesis, would you reject it?  Answer "yes", "no", or "can't tell".
#
# [_choice]
#
# (3)  Suppose that for a given data set of $D$, a 97% confidence interval is calculated to be (25.6,41.1).  If you were to perform a hypothesis test at the 1% significance level to test the null hypothesis, would you reject it?  Answer "yes", "no", or "can't tell".
#
# [_choice]
# Out:
# Overwriting final2016/gust63.imd

# %%
# %%writefile final2016/MarkovChebyshevA.imd
# ```python
# #import random
# k=random.randint(2,5)
# l=random.randint(2,5)
# #k,l
# ```
#
# ## Markov and Chebyshev bounds I
# (10 points)
#
# Suppose $X$ is a non-negative random variable Whose expected value is $\mu=E(X)$.
#
# Which of the following statements are true?
#
# [x] $\;\;P(X \leq \k \mu) \geq 1-(1/\k)$
# [x] $\;\;P(X \geq \k \mu) \leq (1/\k)$
# [] $\;\;P(X \leq \k \mu) \leq 1-(1/\k)$
# [] $\;\;P(X \geq \k \mu) \geq (1/\k)$
#
# Suppose $Y$ is a random variable over both negative and positive reals with mean $\mu=E(Y)$ and variance $\sigma^2=Var(Y)$
#
# Which of the following statements are true?
# [ ] $\;\;P(Y \geq \l \mu) \leq 1/\l$
# [ ] $\;\;P(|Y-\mu| \geq \l \sigma) \geq (1/\l)^2 $
# [x] $\;\;P(|Y-\mu| \geq \l \sigma) \leq (1/\l)^2 $
# [x] $\;\;P(|Y-\mu| \leq \l \sigma) \geq 1-(1/\l)^2 $
# [ ] $\;\;P(|Y-\k \mu| \geq \l \sigma) \geq (1/\l)^2 $
# Out:
# Overwriting final2016/MarkovChebyshevA.imd

# %%
# %%writefile final2016/q4_2.imd
# ```python
# ns = random.randrange(4,6,1)
# nr = random.randrange(10,16,1)
# n = ns*nr
#
# solution1 = "C({0},2)".format(nr)
# solution2 = "{0}-2".format(nr)
# solution3 = "C({0},2)^2".format(ns)
# solution4 = "{0}".format(ns)
# solution5 = "C({1},2)*({1}-2)*(C({0},2)^2)*{0}".format(ns,nr)
# solution6 = "C({1},2)*({1}-2)*(C({0},2)^2)*{1}/C({2},5)".format(ns,nr,n)
#
# solutions = [solution1,solution2,solution3,solution4,solution5,solution6]
# ```
#
# ### Two Pairs ###
# (10 points)
#
# You have a shuffled non-standard deck that has \$ns suits and \$nr ranks.
#
# You pick 5 cards from the deck. What is the probability that you would get
# "two pairs". Each pair is a set of two cards with the same rank,
# the two pairs should have different ranks
# (otherwise it would be a "four").
#
# * The number of possibilities for the ranks of the two pairs is
#
# [_]
#
# * The number of possibilities for the rank of the single is
#
# [_]
#
# * The number of possibilities for the suits of the two pairs is
#
# [_]
#
# * The number of possibilities for the suit of the single is
#
# [_]
#
# * Thus the number of hands with exactly two pairs is
#
# [_]
#
# * The ratio of this number to the number of all hands
#
# [_]
# Out:
# Overwriting final2016/q4_2.imd

# %%
# %%writefile final2016/ShareCandy_ZZ.imd
# ```python
# k = random.randrange(8,15,1)
# r = random.randrange(8,15,1)
#
# while(k == r):
#     k = random.randrange(8,15,1)
#     r = random.randrange(8,15,1)
#
# solution1 = "C({0}+3,3)".format(k)
# solution2 = "C({0}+3,3)".format(r)
# solution3 = "C({0}+3,3) * C({1}+3,3)".format(k,r)
# solution4 = "C({0},3)".format(k)
# solution5 = "C({0},3)".format(r)
# solution6 = "C({0},3) * C({1},3)".format(k,r)
#
# solutions = [solution1, solution2, solution3, solution4, solution5, solution6]
# ```
#
# #### Candice shares Candy with her Little Brothers ####
# (6 points)
#
# After a (not very successful) trick or treating round, Candice has \$k Tootsie rolls and \$r Twizzlers in her pillow case. Her mother asks her to share the loot with her three younger brothers. (She can choose to keep some or none for herself, and can choose to give some or none to any of her brothers.)
#
# o How many different ways can she do this?
#
# First of all, let's find out how many ways can she share Tootsie rolls with her three brothers?
#
# [_]
#
# Then, let's find out how many ways can she share her Twizzlers?
#
# [_]
#
# Now, based on the previous two solutions, how many different ways can she share the loot with her brothers?
#
# [_]
#
# How many different ways can she do this after her mother warns her to give at least one of each type of candies to each of her brothers?
#
# Again, how many ways can she share Tootsie rolls when she has to give at least one Tootsie roll to each of her brothers?
#
# [_]
#
# How many ways can she share her Twizzlers when she has to give at least one Twizzler to each of her brothers?
#
# [_]
#
# Now, based on the previous two solutions, how many different ways can she share the loot with her brothers after her mother warns her?
#
# [_]
# Out:
# Overwriting final2016/ShareCandy_ZZ.imd

# %%
# !ls -l final2016/
# Out:
# total 120
# -rw-r--r--  1 yoavfreund  staff   817 Dec  4 18:32 1.imd
# -rw-r--r--  1 yoavfreund  staff   545 Dec  5 18:09 CDFProblem1.imd
# -rw-r--r--  1 yoavfreund  staff   542 Dec  5 18:09 CDFProblem2.imd
# -rw-r--r--  1 yoavfreund  staff  2112 Dec  5 18:38 HeavyLightTails2.imd
# -rw-r--r--  1 yoavfreund  staff   850 Dec  5 18:38 MarkovChebyshevA.imd
# -rw-r--r--  1 yoavfreund  staff  1704 Dec  5 18:38 ShareCandy_ZZ.imd
# -rw-r--r--  1 yoavfreund  staff  5431 Dec  5 18:38 cov_dep_uncor1.imd
# -rw-r--r--  1 yoavfreund  staff  5456 Dec  5 18:38 cov_dep_uncor2.imd
# -rw-r--r--  1 yoavfreund  staff  2158 Dec  5 18:38 gust63.imd
# -rw-r--r--  1 yoavfreund  staff  1379 Dec  5 18:09 probs_43_w_randomization.imd
# -rw-r--r--  1 yoavfreund  staff  1141 Dec  5 18:38 q4_2.imd
# -rw-r--r--  1 yoavfreund  staff  1022 Dec  5 18:38 sw10_1_33.imd
# -rw-r--r--  1 yoavfreund  staff   882 Dec  5 18:38 ur_pb_9_2.imd

# %%
from glob import glob
i=0
for file in glob('final2016/*'):
    with open(file,'r') as F:
        i+=1
        print i,'-'*20,file
        for line in F.readlines():
            if 'point' in line or '##' in line:
                print line,
# Out:
# 1 -------------------- final2016/1.imd
# ## Covariance and Dependence
# (10 points)
# 2 -------------------- final2016/CDFProblem1.imd
# ### CDF problem (version 1)
# (15 points)
# #### Figure
# mixture of two uniform distributions and a point mass.
# * There is a point mass distribution at [2] whose weight is [0.2]
# 3 -------------------- final2016/CDFProblem2.imd
# ### CDF problem (version 2)
# (15 points)
# #### Figure
# mixture of two uniform distributions and a point mass.
# * There is a point mass distribution at [2] whose weight is [0.3]
# 4 -------------------- final2016/cov_dep_uncor1.imd
# #### Written by Yoav Freund 11/3/2016
# ### Covariance Calculations (Version 1)
# (10 points)
# ###(1) What is the distribution over $X$?
# ###(2) What is the distribution over $Y$?
# ###(3) What is the relationship between $X$ and $Y$ ?
# 5 -------------------- final2016/cov_dep_uncor2.imd
# #### Written by Yoav Freund 11/3/2016
# ### Covariance Calculations (Version 2)
# (10 points)
# ...

# %%
# %%writefile finalProblems.txt
# 1 -------------------- final2016/sw10_1_33.imd
# ## Combinatorics: letter combinations
# (10 points)
# 2 -------------------- final2016/q4_2.imd
# ### Two Pairs ###
# (10 points)
# 3 -------------------- final2016/ShareCandy_ZZ.imd
# #### Candice shares Candy with her Little Brothers ####
# (10 points)
# 4 -------------------- final2016/probs_43_w_randomization.imd
# ## Bayes: Gender and color-blindness
# (5 points)
# 5.1 -------------------- final2016/CDFProblem1.imd
# ### CDF problem (version 1)
# (15 points)
# 5.2 -------------------- final2016/CDFProblem2.imd
# ### CDF problem (version 2)
# (15 points)
# 6 -------------------- final2016/MarkovChebyshevA.imd
# ## Markov and Chebyshev bounds
# (10 points)
# 7 -------------------- final2016/1.imd
# ## Covariance and Dependence
# (10 points)
# 8.1 -------------------- final2016/cov_dep_uncor1.imd
# ### Covariance Calculations (Version 1)
# (10 points)
# 8.2 -------------------- final2016/cov_dep_uncor2.imd
# ### Covariance Calculations (Version 2)
# (10 points)
# 9 -------------------- final2016/HeavyLightTails2.imd
# ## Heavy and light tails
# (20 points)
# 10 -------------------- final2016/ur_pb_9_2.imd
# ### Poisson process
# (10 points)
# 11 -------------------- final2016/gust63.imd
# ### Hypothesis testing and confidence intervals
# (5 points)
# Out:
# Writing finalProblems.txt

# %%
import re
pat = re.compile(r'(\d+)(.\d+)?[ -]+final2016/(.*imd)')
with open('finalProblems.txt','r') as F:
    for line in F.readlines():
        M=pat.search(line)
        if M:
            num,ver,name = M.groups()
            num='%02d'%int(num)
            print num,name
            path1='final2016/'+name
            if ver:
                path2='nfinal2016/'+num+ver+'.'+name
            else:
                path2='nfinal2016/'+num+'.'+name
            # !cp $path1 $path2
# Out:
# 01 sw10_1_33.imd
# 02 q4_2.imd
# 03 ShareCandy_ZZ.imd
# 04 probs_43_w_randomization.imd
# 05 CDFProblem1.imd
# 05 CDFProblem2.imd
# 06 MarkovChebyshevA.imd
# 07 1.imd
# 08 cov_dep_uncor1.imd
# 08 cov_dep_uncor2.imd
# 09 HeavyLightTails2.imd
# 10 ur_pb_9_2.imd
# 11 gust63.imd

# %%
# !ls nfinal2016
# Out:
# 01.sw10_1_33.imd                07.1.imd
# 02.q4_2.imd                     08.1.cov_dep_uncor1.imd
# 03.ShareCandy_ZZ.imd            08.2.cov_dep_uncor2.imd
# 04.probs_43_w_randomization.imd 09.HeavyLightTails2.imd
# 05.1.CDFProblem1.imd            10.ur_pb_9_2.imd
# 05.2.CDFProblem2.imd            11.gust63.imd
# 06.MarkovChebyshevA.imd

# %%
name='BayesConditional'
# !ls -l $name/Bayes2.imd
# Out:
# -rw-r--r--  1 yoavfreund  staff  1273 Nov 26 16:54 BayesConditional/Bayes2.imd

# %%
print "%03d"%5
# Out:
# 005

# %%
# !rm nfinal2016/*
